# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d samps74/e-commerce-customer-behavior-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/samps74/e-commerce-customer-behavior-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#   0% 0.00/3.33k [00:00<?, ?B/s]
# 100% 3.33k/3.33k [00:00<00:00, 5.32MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/e-commerce-customer-behavior-dataset.zip')
df
# Out:
#     Customer ID  Age  Gender Location  Annual Income  \
# 0          1001   25  Female   City D          45000
# 1          1001   28  Female   City D          52000
# 2          1001   28  Female   City D          65000
# 3          1001   45  Female   City D          70000
# 4          1002   34    Male   City E          45000
# 5          1003   56   Other   City F          90000
# 6          1004   29  Female   City G          60000
# 7          1005   42    Male   City H          75000
# 8          1006   51   Other   City I          85000
# 9          1007   36  Female   City J          55000
# 10         1008   48    Male   City K          80000
# 11         1009   25   Other   City L          40000
# 12         1001   45  Female   City D          75000
# 13         1002   32    Male   City A          50000
# 14         1003   60   Other   City B          80000
# 15         1004   28  Female   City C          45000
# 16         1005   55    Male   City E          90000
# ...

# %%
# !kaggle datasets download -d jacopoferretti/chinook-music-database
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jacopoferretti/chinook-music-database
# License(s): CC0-1.0
# ...
# 100% 144k/144k [00:00<00:00, 429kB/s]
# 100% 144k/144k [00:00<00:00, 428kB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/lung-cancer-data.zip')
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
# !kaggle datasets download -d kashifsahil/16000-movies-1910-2024-metacritic
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kashifsahil/16000-movies-1910-2024-metacritic
# License(s): CC0-1.0
# ...
#   0% 0.00/3.16M [00:00<?, ?B/s]
# 100% 3.16M/3.16M [00:00<00:00, 140MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/16000-movies-1910-2024-metacritic.zip')
df
# Out:
#        Unnamed: 0                                    Title  Release Date  \
# 0               0                           Dekalog (1988)  Mar 22, 1996
# 1               1                        Three Colors: Red  Nov 23, 1994
# 2               2                           The Conformist  Oct 22, 1970
# 3               3                              Tokyo Story  Mar 13, 1972
# 4               4                 The Leopard (re-release)  Aug 13, 2004
# ...           ...                                      ...           ...
# 16285       16285                              Boys to Men  Apr 27, 2001
# 16286       16286  Saint Misbehavin': The Wavy Gravy Movie  Dec 10, 2010
# 16287       16287                               Collectors   Oct 1, 2000
# 16288       16288                               Bonhoeffer  Jun 20, 2003
# 16289       16289                               7th Street  Jan 17, 2003
#
#                                              Description  Rating  \
# ...

# %%
# !kaggle datasets download -d rishabhbhartiya/taarak-mehta-ka-ooltah-chashmah-episode-dateset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rishabhbhartiya/taarak-mehta-ka-ooltah-chashmah-episode-dateset
# License(s): CC-BY-NC-SA-4.0
# ...
#   0% 0.00/383k [00:00<?, ?B/s]
# 100% 383k/383k [00:00<00:00, 85.6MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/taarak-mehta-ka-ooltah-chashmah-episode-dateset.zip')
df
# Out:
#       Unnamed: 0  episode_number  \
# 0              0               1
# 1              1               2
# 2              2               3
# 3              3               4
# 4              4               5
# ...          ...             ...
# 4090        4090            4096
# 4091        4091            4097
# 4092        4092            4098
# 4093        4093            4099
# 4094        4094            4100
#
#                                           Episode_title  \
# 0     Taarak Mehta Introduces Himself And Society Me...
# 1      Jethalal's Son Tapu Decides To Spend His Holiday
# 2                   Tapu Has Been The Worry Of Jethalal
# 3                 Daya Approaches Taarak Mehta For Help
# 4                              Jethalal In Huge Trouble
# ...                                                 ...
# 4090                                  Mission Paar Paar
# 4091                             Ganda Paani Ka Istamal
# ...

# %%
# !kaggle datasets download -d shubhamchandra235/imdb-and-tmdb-movie-metadata-big-dataset-1m
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shubhamchandra235/imdb-and-tmdb-movie-metadata-big-dataset-1m
# License(s): MIT
# ...
#  99% 393M/397M [00:08<00:00, 52.6MB/s]
# 100% 397M/397M [00:08<00:00, 46.4MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/imdb-and-tmdb-movie-metadata-big-dataset-1m.zip')
df
# Out:
#               id                         title  vote_average  vote_count  \
# 0          27205                     Inception         8.364       34495
# 1         157336                  Interstellar         8.417       32571
# 2            155               The Dark Knight         8.512       30619
# 3          19995                        Avatar         7.573       29815
# 4          24428                  The Avengers         7.710       29166
# ...          ...                           ...           ...         ...
# 1072250   715344                    Affability         0.000           0
# 1072251   715345         Such a Beautiful Town         0.000           0
# 1072252   715347                          Sura         0.000           0
# 1072253   715351                Ανεμοστρόβιλος         0.000           0
# 1072254  1324976  The Frogs That Wanted a King         0.000           0
#
#            status release_date     revenue  runtime  adult  \
# ...

# %%
# !kaggle datasets download -d andrsmosquera/crticas-pelculas-filmaffinity-en-espaol-netflix
# Out:
# Dataset URL: https://www.kaggle.com/datasets/andrsmosquera/crticas-pelculas-filmaffinity-en-espaol-netflix
# License(s): CC0-1.0
# ...
#  89% 5.00M/5.60M [00:00<00:00, 44.8MB/s]
# 100% 5.60M/5.60M [00:00<00:00, 48.6MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/taarak-mehta-ka-ooltah-chashmah-episode-dateset.zip')
df
# Out:
#       Unnamed: 0  episode_number  \
# 0              0               1
# 1              1               2
# 2              2               3
# 3              3               4
# 4              4               5
# ...          ...             ...
# 4090        4090            4096
# 4091        4091            4097
# 4092        4092            4098
# 4093        4093            4099
# 4094        4094            4100
#
#                                           Episode_title  \
# 0     Taarak Mehta Introduces Himself And Society Me...
# 1      Jethalal's Son Tapu Decides To Spend His Holiday
# 2                   Tapu Has Been The Worry Of Jethalal
# 3                 Daya Approaches Taarak Mehta For Help
# 4                              Jethalal In Huge Trouble
# ...                                                 ...
# 4090                                  Mission Paar Paar
# 4091                             Ganda Paani Ka Istamal
# ...

# %%
# !kaggle datasets download -d farialmahmod/textile-exports-of-bangladesh
# Out:
# Dataset URL: https://www.kaggle.com/datasets/farialmahmod/textile-exports-of-bangladesh
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#   0% 0.00/376 [00:00<?, ?B/s]
# 100% 376/376 [00:00<00:00, 657kB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/textile-exports-of-bangladesh.zip')
df
# Out:
#    Year  Amount (in USD Million) Largest Importers Apparel Types
# 0  2023                 47386.26      USA, Germany          Knit
# 1  2022                 45709.15      USA, Germany          Knit
# 2  2021                 35811.87      USA, Germany          Knit
# 3  2020                 27470.73       UK, Germany          Knit
# 4  2019                 33072.38      Germany, USA         Woven
# 5  2018                 32926.88      Germany, USA         Woven
